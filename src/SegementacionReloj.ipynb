# %%
import cv2 as cv
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
image = cv.imread('imagenes/reloj.jpg',0)
plt.imshow(image, 'gray')

# %%
histg = cv.calcHist([image],[0],None,[256],[0,256])
plt.plot(histg) 
plt.show()

# %%
ret,thresh1 = cv.threshold(image_new,145,260,cv.THRESH_BINARY)
#thresh1 = cv.adaptiveThreshold(image,255,cv.ADAPTIVE_THRESH_GAUSSIAN_C,cv.THRESH_BINARY,255,2)
plt.imshow(image_new, 'gray')
