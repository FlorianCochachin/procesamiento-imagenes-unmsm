# %%
import cv2 as cv
import imutils
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
imagen = cv.imread('imagenes/onerice.png')
imgGray = cv.cvtColor(imagen, cv.COLOR_BGR2GRAY)
plt.imshow(imgGray, 'gray')

# %%
def mascara(imagen):
    a, b = imagen.shape
# Out:
# conceptosBasicos.ipynb  Mascaras.ipynb            Untitled1.ipynb
# Ejercicios.ipynb        SegementacionReloj.ipynb  Untitled.ipynb
# Histograma.ipynb        Sementacion.ipynb
# imagenes/               Transformaciones.ipynb
