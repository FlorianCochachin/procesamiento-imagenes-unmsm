# %%
import cv2 as cv
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv.imread('imagenes/edificios.jpg', 0)
plt.imshow(img, 'gray')
plt.show()
print(img.shape)
# Out:
# (1210, 800)

# %%
#histograma
#img_prueba = img * (256/110)
a,b = img.shape
datos = np.reshape(img, a * b)
plt.hist(datos, bins=256, edgecolor = 'black',  linewidth=1)
#plt.hist(h)
plt.show()
plt.show()

# %%
img_prueba = 0.4 * img
plt.imshow(img_prueba, 'gray')
plt.show()

# %%
a, b = img_prueba.shape
datos = np.reshape(img_prueba, a * b)
plt.hist(datos, bins=256, edgecolor = 'black',  linewidth=1)
#plt.hist(h)
plt.show()

# %%
imagen_prueba_2 = img_prueba + 130
plt.imshow(imagen_prueba_2, 'gray')
plt.show()

# %%
a, b = imagen_prueba_2.shape
datos = np.reshape(imagen_prueba_2, a * b)
plt.hist(datos, bins=256, edgecolor = 'black',  linewidth=1)
#plt.hist(h)
plt.show()

# %%
#expandir el histograma

img_expan = img_prueba * (255 / 103)
datos = np.reshape(imagen_prueba_2, a * b)
plt.hist(datos, bins=256, edgecolor = 'black',  linewidth=1)
#plt.hist(h)
plt.show()

# %%
img = cv.imread('imagenes/IMG01.png', 0)
plt.imshow(img, 'gray')
plt.show()
print(img.shape)
# Out:
# (512, 512)
