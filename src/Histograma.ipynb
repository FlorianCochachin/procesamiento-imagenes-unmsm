# %%
import cv2 as cv
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv.imread('tokio.jpg', 0)
plt.imshow(img)
plt.show()

# %%
#histograma
img_prueba = img *(256/110)
datos = np.reshape(img_prueba, a * b)
plt.hist(datos, bins=256, edgecolor = 'black',  linewidth=1)
#plt.hist(h)
plt.show()
plt.imshow(img_prueba)
plt.show()

# %%
img_1 = 0.5 * img
plt.imshow(img_1)
plt.show()

# %%
datos = np.reshape(img_1, a * b)
plt.hist(datos, bins=256, edgecolor = 'black',  linewidth=1)
#plt.hist(h)
plt.show()

# %%
img_2 = img_1 + 200
plt.imshow(img_2)
plt.show()

# %%
datos = np.reshape(img_2, a * b)
plt.hist(datos, bins=256, edgecolor = 'black',  linewidth=1)
#plt.hist(h)
plt.show()

# %%
#ecualizacio del histograma
