# %% [markdown]
# Defición de operador matemático convolución

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv

# %%
xt = np.array([1,2,4,3,7,2])
gt = np.array([1,0,8])

# %%
yt = np.convolve(xt,gt,'full')
print("xt*gt->",yt)
# Out:
# xt*gt-> [ 1  2 12 19 39 26 56 16]

# %% [markdown]
# Aplicación en señales: Filtrado simple con una ventana promedio

# %%
n = 1000
i = np.array(range(n))
t = i * 8 * np.pi / n
x = np.sin(t) * np.sin(2*t) #señal original

r = np.random.random_sample(size = n) - 0.5 #ruido
xr = x + r #señal con ruido
plt.figure(figsize=(20,9))
plt.plot(t,xr)
plt.plot(t,x)
plt.legend(['xr', 'x'])
plt.show()

# %% [markdown]
# Filtrar el ruido

# %%
m = 20
g = np.ones((m)) / m
y = np.convolve(xr, g, 'same')
plt.figure(figsize=(20,9))
plt.plot(t,x)
plt.plot(t,y)
plt.legend(['x','y'])
plt.show()

# %% [markdown]
# 2) Separación de dos señaes (con Gausianas)

# %% [raw]
# x1: Primera señal de frecuencia baja;
# x2: Segunda señal de frecuencia alta;
# x = x1 + x2;
# z = x + ruido;
#
# Problema: a partir de z encontrar x1 y x2

# %% [raw]
# Solución:
# y1 = filtro pasa(muy) bajo de z con un Gausiana h1 de ancho 7: aqui solo pasa las sinusoide de frecuencia baja.
# y2 = filtro pasa bajo z con una Gausiana h1 de ancho 1:a qui se elimina el ruido, y2 es parecido a x

# %%
m = 1000
i = np.array(range(n))
t = i * 8 * np.pi/n
x1 = np.sin(t)
x2 = 0.3*np.sin(20*t)
x = x1 + x2
r = np.random.random_sample(size = n) - 0.5 #ruido
z = x + r
plt.figure(figsize=(20,9))
plt.plot(t,x1)
plt.plot(t,x2)
plt.plot(t,z)
plt.legend(['x1','x2','z'])
plt.show()

# %%
m = 25
h1 = cv.getGaussianKernel(m,7)
h2 = cv.getGaussianKernel(m,1)
plt.plot(h1)
plt.plot(h2)
plt.legend(['h1','h2'])
plt.show()

# %%
y1 = np.convolve(z,h1[:,0],'same')
y2 = np.convolve(z,h2[:,0], 'same')
plt.figure(figsize=(20,9))
plt.plot(y2)
plt.plot(y1)
plt.legend(['y2','y1'])
plt.show()

# %%
plt.figure(figsize=(20,9))
plt.plot(x1)
plt.plot(y1)
plt.plot(x1-y1)
plt.legend(['x1','y1', 'error'])
plt.show()

# %%
y3 = -y1 + y2
plt.figure(figsize=(20,9))
plt.plot(x2)
plt.plot(y3)
plt.plot(x2 - y3)
plt.legend(['x2','y2-y1', 'error'])
plt.show()

# %% [markdown]
# Simulación de una imagen con movimiento horizontal

# %%
imagen = cv.imread('imagenes/zebra_bw.png',0)
#imagen = cv.cvtColor(imagen_1, cv.COLOR_RGB2GRAY)

# %%
plt.imshow(imagen, 'gray')

# %%
#convolución linea por linea
m = 20
g = np.ones((m)) / m
a,b = imagen.shape
y = np.zeros((a,b))
for i in range(a):
    y[i,:] = np.convolve(imagen[i,:], g, 'same')
#plt.show(y)
plt.imshow(y,'gray')

# %%
h = g.reshape(1,m)
y = cv.filter2D(imagen,-1,h)
plt.imshow(y, 'gray')

# %% [markdown]
# Detección de bordes

# %%
xd = imagen.astype(float)
th = 40
h1 = np.array([-1,0,1])
y1 = np.abs(cv.filter2D(xd, -1, h1))
z1 = y1 > th

h2 = h1.reshape(1,3)
y2 = np.abs(cv.filter2D(xd, -1, h2))
z2 = y2 > th
z = np.logical_or(z1,z2)
plt.imshow(z)

# %%
#(a,b) = imagen.shape
#d = np.zeros((a,b,3))
#d[:,:,1] = np.multiply(imagen, (1-z))
#d[:,:,0] = np.multiply(imagen, (1-z))
#d[:,:,2] = imagen
#plt.imshow(d)
print(z)
#contours, _ = cv.findContours(, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_SIMPLE)
#cv.drawContours(imagen, contours, -1, (0, 255, 0), 2)  # Pinta los bordes en verde (0, 255, 0) con un grosor de 2 píxeles
#plt.imshow(contours)
# Out:
# [[False False  True ... False False False]
#  [False False  True ... False False False]
#  [False False  True ... False False False]
#  ...
#  [False False False ...  True  True False]
#  [False False False ...  True  True False]
#  [False False False ...  True  True False]]
